# %%
import numpy as np 
import math as m
import matplotlib.pyplot as plt

def celsius_to_kelvin(D):
    K = D + 273.15
    return K

def kelvin_to_celsius(K):
    D = K - 273.15
    return D

def eng(N):
    print('{:e}'.format(N))
    return

# %%
J = 20
c = 48
k = 28.8
w_0 = 4
theta_0 = 0

# %%
delta = (c/J)**2 - 4*k/J

# %%
delta
# Out:
# 0.0

# %%
x_1 = ((c/J)**2)+(delta**0.5)/2
x_2 = ((c/J)**2)-(delta**0.5)/2

# %%
x_1
# Out:
# 5.76

# %%
x_2
# Out:
# 5.76

# %%
t = np.linspace(0, 4*np.pi, num=1000)
theta = -w_0*np.exp(x_1*t)*t

# %% [markdown]
# $\theta$

# %%
fig = plt.figure(figsize=[16,9])
ax = fig.subplots(1,1)

ax.set_ylabel('$𝜃(rad)$',fontsize=16)
ax.set_xlabel('$t(s)$',fontsize=16)
ax.set_title('Gráfico do angulo $𝜃$ em função do tempo ($t$)',fontsize=20)

ax.plot(t, theta,'r', linewidth=4)

ax.grid()

plt.show()
fig.savefig('angulo_vs_tempo.png', bbox_inches='tight')
