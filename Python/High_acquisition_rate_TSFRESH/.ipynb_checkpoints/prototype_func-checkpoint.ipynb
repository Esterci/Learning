# %%
#from unified_bib import DataSlicer,PCA_calc,SODA,GroupingAlgorithm,Classification,tsfresh_chucksize, dynamic_tsfresh, PCA_projection, Model_Predict, classifiers_train

import unified_bib as uf
from importlib import reload
import numpy as np
import os
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler
from tsfresh.feature_extraction import extract_features, ComprehensiveFCParameters
from tsfresh.feature_extraction.settings import from_columns
from tsfresh.feature_extraction import feature_calculators
from tsfresh.feature_extraction import EfficientFCParameters
import pickle
import pandas as pd
import tsfresh
from psutil import cpu_percent
from tsfresh import extract_features
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute
import matplotlib.pyplot as plt

# %% [markdown]
# # Filtering TSFRESH Features
# - Given an `output_id`, this function withdraw all NaN features from the TSFRESH extraction

# %%
uf.tsfresh_NaN_filter('100')
# Out:
# Feature Extraction: 100%|██████████| 20/20 [08:37<00:00, 25.87s/it]
# Percentage of invalid features:  0.6468305304010349
# Percentage of valid features:  99.35316946959897

# %% [markdown]
# # Using original data
# ## Training phase

# %%
output_id = '100'
full_data = np.genfromtxt('Input/Output_' + output_id + '.csv',
                                delimiter=',')

# %%
target = full_data[:,-1]
ID = full_data[:,0]
diam_target = np.ones((target.shape))

diam_target[target==0] = 0
diam_target[0:112*750] = -1

unique_id = np.unique(ID).tolist()

id_train, id_test = train_test_split(unique_id, test_size=0.3)

train_index =[]
test_index =[]

for i in range(len(ID)):
    if ID[i] in id_train:
        train_index.append(i)
        
    elif ID[i] in id_test:
        test_index.append(i)

train_set = full_data[train_index,:]
test_set = full_data[test_index,:]

_,train_index_first_occurance = np.unique(train_set[:,0],return_index=True)
_,test_index_first_occurance = np.unique(test_set[:,0],return_index=True)

train_set_target = train_set[train_index_first_occurance.tolist(),-1]
test_set_target = test_set[test_index_first_occurance.tolist(),-1]

train_set_diam = diam_target[train_index_first_occurance.tolist()]
test_set_diam = diam_target[test_index_first_occurance.tolist()]

# %%
SelectedFeatures = uf.tsfresh_chucksize(train_set,output_id)
#SelectedFeatures = uf.tsfresh_extraction(9)
# Out:
# Feature Extraction: 100%|██████████| 20/20 [01:07<00:00,  3.38s/it]
# Feature Extraction: 100%|██████████| 20/20 [01:06<00:00,  3.30s/it]
# Feature Extraction: 100%|██████████| 20/20 [01:04<00:00,  3.23s/it]
# Feature Extraction: 100%|██████████| 20/20 [01:07<00:00,  3.36s/it]
# Feature Extraction: 100%|██████████| 20/20 [01:01<00:00,  3.09s/it]
# Feature Extraction: 100%|██████████| 20/20 [01:01<00:00,  3.09s/it]

# %%
ReducedFeatures = uf.PCA_calc(SelectedFeatures,3,'Calc') # (Feautures selecionadas, numero de PC's a manter, mode ('Test','Calc','Specific', 'Analytics'))
# Out:
#
# PCA Control Output
# ----------------------------------
# Variation maintained: 60.14
#
# Filtered Features
# --------------------
# 526
# 900
# --------------------
# Reduced Features
# --------------------
# 526
# 3

# %% [markdown]
# ## Testing phase

# %%
extracted_features, ets = uf.dynamic_tsfresh(test_set, 'test')
# Out:
# Feature Extraction: 100%|██████████| 226/226 [00:27<00:00,  8.24it/s]
# Feature Extraction: 100%|██████████| 226/226 [00:31<00:00,  7.20it/s]
# Feature Extraction: 100%|██████████| 226/226 [00:31<00:00,  7.17it/s]
# Feature Extraction: 100%|██████████| 226/226 [00:24<00:00,  9.04it/s]
# Feature Extraction: 100%|██████████| 226/226 [00:20<00:00, 11.23it/s]
# Feature Extraction: 100%|██████████| 226/226 [00:16<00:00, 14.01it/s]

# %%
projected_features = uf.PCA_projection(extracted_features)
# Out:
# Variation maintained: 60.21

# %%
uf.Classification_it(ReducedFeatures['ReducedFeatures'],projected_features,train_set_target,test_set_target)
# Out:
# -------------------------------------
#                   Accuracy [%] Precision [%] Recall [%]  F1 [%]
# Nearest Neighbors       94.25%        90.71%    100.00%  95.13%
# Linear SVM              98.67%       100.00%     97.64%  98.80%
# RBF SVM                 67.70%        63.50%    100.00%  77.68%
# Gaussian Process        87.17%        81.41%    100.00%  89.75%
# Decision Tree           99.56%        99.22%    100.00%  99.61%
# Random Forest           96.90%        97.62%     96.85%  97.23%
# Neural Net              98.23%        96.95%    100.00%  98.45%
# AdaBoost                98.67%        97.69%    100.00%  98.83%
# Naive Bayes             64.16%        97.92%     37.01%  53.71%
# QDA                     97.35%        95.49%    100.00%  97.69%

# %%
training_data = ReducedFeatures['ReducedFeatures']
test_data = projected_features

fig = plt.figure(figsize=[14,10])
ax = fig.add_subplot(111, projection='3d')

# Treino

ax.scatter(training_data[train_set_target== 0,0], 
           training_data[train_set_target== 0,1], 
           training_data[train_set_target== 0,2], 
           c = 'b',label='Treino-ferramenta boa')

ax.scatter(training_data[train_set_target == 1,0], 
           training_data[train_set_target == 1,1], 
           training_data[train_set_target == 1,2], 
           c = 'r',label='Treino-ferramenta ruim')

# Teste
           
ax.scatter(test_data[test_set_target== 0,0], 
           test_data[test_set_target== 0,1], 
           test_data[test_set_target== 0,2], 
           c = 'g',label='Teste-ferramenta boa')

ax.scatter(test_data[test_set_target == 1,0], 
           test_data[test_set_target == 1,1], 
           test_data[test_set_target == 1,2], 
           c = 'purple',label='Teste-ferramenta ruim')

plt.ylabel('PC2',fontsize = 20,labelpad=18)
plt.xlabel('PC1',fontsize = 20, labelpad=18)
ax.set_zlabel('PC3', fontsize = 20, labelpad=12)
plt.tick_params(axis='x', labelsize=16)
plt.tick_params(axis='y', labelsize=16)
plt.tick_params(axis='z', labelsize=16)

ax.grid()
plt.legend()

plt.show()

# %% [markdown]
# # Misc

# %%
reload(uf)
# Out:
# <module 'unified_bib' from '/home/thiago/Repositories/Learning/Python/High_acquisition_rate_TSFRESH/unified_bib.py'>

# %%
projected_features[:,1] *= -1

# %%
SODA_parameters, processing_parameters = uf.SODA(ReducedFeatures,2.5,8,0.25) # (Features reduzidas, granularidade mínima, granularidade máxima, passo)

# %%
ClassificationPar = uf.GroupingAlgorithm(SODA_parameters,95, processing_parameters) # (Labels do SODA, Porcentagem de definição, numero de ID's boas, parametros de processamento)
# Out:
#
# Grouping Algorithm Control Output
# ----------------------------------
# SODA_euclidean_label_104_2.00.csv
# Number of data clouds: 2
# Number of good tools groups: 0
# Number of worn tools groups: 1
# Number of excluded data clouds: 1
# Number of samples: 1722
# Number of good tools samples: 10
# Number of worn tools samples: 846
# Number of excluded samples: 866
# Data representation loss: 50.29
# Analyse execution time: 2.017764 segundos
# Avarage CPU usage: 17.82
# ---------------------------------------------------
# SODA_euclidean_label_104_2.25.csv
# Number of data clouds: 2
# Number of good tools groups: 0
# Number of worn tools groups: 1
# Number of excluded data clouds: 1
# Number of samples: 1722
# Number of good tools samples: 20
# Number of worn tools samples: 761
# Number of excluded samples: 941
# Data representation loss: 54.65
# Analyse execution time: 3.032117 segundos
# Avarage CPU usage: 17.36
# ---------------------------------------------------
# SODA_euclidean_label_104_2.50.csv
# Number of data clouds: 5
# Number of good tools groups: 1
# Number of worn tools groups: 1
# Number of excluded data clouds: 3
# Number of samples: 1722
# Number of good tools samples: 464
# Number of worn tools samples: 243
# Number of excluded samples: 1015
# Data representation loss: 58.94
# Analyse execution time: 3.014940 segundos
# Avarage CPU usage: 23.88
# ---------------------------------------------------
# SODA_euclidean_label_104_2.75.csv
# Number of data clouds: 7
# Number of good tools groups: 2
# Number of worn tools groups: 2
# Number of excluded data clouds: 3
# Number of samples: 1722
# Number of good tools samples: 597
# Number of worn tools samples: 429
# Number of excluded samples: 696
# Data representation loss: 40.42
# Analyse execution time: 4.042007 segundos
# Avarage CPU usage: 19.88
# ---------------------------------------------------
# SODA_euclidean_label_104_3.00.csv
# Number of data clouds: 12
# Number of good tools groups: 5
# Number of worn tools groups: 5
# Number of excluded data clouds: 2
# Number of samples: 1722
# Number of good tools samples: 703
# Number of worn tools samples: 729
# Number of excluded samples: 290
# Data representation loss: 16.84
# Analyse execution time: 4.026687 segundos
# Avarage CPU usage: 22.43
# ---------------------------------------------------
# SODA_euclidean_label_104_3.25.csv
# Number of data clouds: 18
# Number of good tools groups: 8
# Number of worn tools groups: 8
# Number of excluded data clouds: 2
# Number of samples: 1722
# Number of good tools samples: 717
# Number of worn tools samples: 810
# Number of excluded samples: 195
# Data representation loss: 11.32
# Analyse execution time: 5.056201 segundos
# Avarage CPU usage: 20.10
# ---------------------------------------------------
# SODA_euclidean_label_104_3.50.csv
# Number of data clouds: 22
# Number of good tools groups: 11
# Number of worn tools groups: 11
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 6.060489 segundos
# Avarage CPU usage: 18.11
# ---------------------------------------------------
# SODA_euclidean_label_104_3.75.csv
# Number of data clouds: 29
# Number of good tools groups: 12
# Number of worn tools groups: 14
# Number of excluded data clouds: 3
# Number of samples: 1722
# Number of good tools samples: 617
# Number of worn tools samples: 973
# Number of excluded samples: 132
# Data representation loss: 7.67
# Analyse execution time: 7.074345 segundos
# Avarage CPU usage: 22.03
# ---------------------------------------------------
# SODA_euclidean_label_104_4.00.csv
# Number of data clouds: 42
# Number of good tools groups: 20
# Number of worn tools groups: 20
# Number of excluded data clouds: 2
# Number of samples: 1722
# Number of good tools samples: 663
# Number of worn tools samples: 978
# Number of excluded samples: 81
# Data representation loss: 4.70
# Analyse execution time: 8.087301 segundos
# Avarage CPU usage: 19.79
# ---------------------------------------------------
# SODA_euclidean_label_104_4.25.csv
# Number of data clouds: 56
# Number of good tools groups: 25
# Number of worn tools groups: 30
# Number of excluded data clouds: 1
# Number of samples: 1722
# Number of good tools samples: 735
# Number of worn tools samples: 974
# Number of excluded samples: 13
# Data representation loss: 0.75
# Analyse execution time: 8.092271 segundos
# Avarage CPU usage: 21.57
# ---------------------------------------------------
# SODA_euclidean_label_104_4.50.csv
# Number of data clouds: 88
# Number of good tools groups: 36
# Number of worn tools groups: 51
# Number of excluded data clouds: 1
# Number of samples: 1722
# Number of good tools samples: 737
# Number of worn tools samples: 976
# Number of excluded samples: 9
# Data representation loss: 0.52
# Analyse execution time: 10.119960 segundos
# Avarage CPU usage: 20.13
# ---------------------------------------------------
# SODA_euclidean_label_104_4.75.csv
# Number of data clouds: 119
# Number of good tools groups: 42
# Number of worn tools groups: 76
# Number of excluded data clouds: 1
# Number of samples: 1722
# Number of good tools samples: 736
# Number of worn tools samples: 976
# Number of excluded samples: 10
# Data representation loss: 0.58
# Analyse execution time: 12.107650 segundos
# Avarage CPU usage: 22.31
# ---------------------------------------------------
# SODA_euclidean_label_104_5.00.csv
# Number of data clouds: 162
# Number of good tools groups: 58
# Number of worn tools groups: 104
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 15.209352 segundos
# Avarage CPU usage: 21.65
# ---------------------------------------------------
# SODA_euclidean_label_104_5.25.csv
# Number of data clouds: 190
# Number of good tools groups: 70
# Number of worn tools groups: 120
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 17.226652 segundos
# Avarage CPU usage: 23.57
# ---------------------------------------------------
# SODA_euclidean_label_104_5.50.csv
# Number of data clouds: 224
# Number of good tools groups: 89
# Number of worn tools groups: 135
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 19.242493 segundos
# Avarage CPU usage: 18.41
# ---------------------------------------------------
# SODA_euclidean_label_104_5.75.csv
# Number of data clouds: 263
# Number of good tools groups: 114
# Number of worn tools groups: 149
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 19.194714 segundos
# Avarage CPU usage: 19.59
# ---------------------------------------------------
# SODA_euclidean_label_104_6.00.csv
# Number of data clouds: 292
# Number of good tools groups: 127
# Number of worn tools groups: 165
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 20.252834 segundos
# Avarage CPU usage: 19.90
# ---------------------------------------------------
# SODA_euclidean_label_104_6.25.csv
# Number of data clouds: 326
# Number of good tools groups: 139
# Number of worn tools groups: 187
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 21.216440 segundos
# Avarage CPU usage: 22.76
# ---------------------------------------------------
# SODA_euclidean_label_104_6.50.csv
# Number of data clouds: 365
# Number of good tools groups: 146
# Number of worn tools groups: 219
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 25.299849 segundos
# Avarage CPU usage: 22.59
# ---------------------------------------------------
# SODA_euclidean_label_104_6.75.csv
# Number of data clouds: 413
# Number of good tools groups: 161
# Number of worn tools groups: 252
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 27.285093 segundos
# Avarage CPU usage: 19.83
# ---------------------------------------------------
# SODA_euclidean_label_104_7.00.csv
# Number of data clouds: 451
# Number of good tools groups: 176
# Number of worn tools groups: 275
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 28.313315 segundos
# Avarage CPU usage: 20.40
# ---------------------------------------------------
# SODA_euclidean_label_104_7.25.csv
# Number of data clouds: 489
# Number of good tools groups: 198
# Number of worn tools groups: 291
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 29.369861 segundos
# Avarage CPU usage: 20.43
# ---------------------------------------------------
# SODA_euclidean_label_104_7.50.csv
# Number of data clouds: 513
# Number of good tools groups: 209
# Number of worn tools groups: 304
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 26.363300 segundos
# Avarage CPU usage: 17.68
# ---------------------------------------------------
# SODA_euclidean_label_104_7.75.csv
# Number of data clouds: 535
# Number of good tools groups: 217
# Number of worn tools groups: 318
# Number of excluded data clouds: 0
# Number of samples: 1722
# Number of good tools samples: 738
# Number of worn tools samples: 984
# Number of excluded samples: 0
# Data representation loss: 0.00
# Analyse execution time: 29.417920 segundos
# Avarage CPU usage: 21.58
# ---------------------------------------------------

# %%
reload(uf)

# %%
# Alarm tag
while True:
    os.system("printf '\a'") # or '\7'
    time.sleep(0.001)

# %%
# Alarm tag
while True:
    os.system("printf '\a'") # or '\7'
    time.sleep(0.001)

# %%
test_tsfresh(SelectedFeatures,extracted_features)

# %%
os.chdir(r'C:\Users\mathe\OneDrive\Documentos\GitHub\Lathes_Tool_Project')

# %%
# .Recovery

if True:
    print('Recovery Control Output')
    print('----------------------------------')

    D_S_parameters =  Recovery('D_S_parameters') 
    ExtractedNames =  Recovery('ExtractedNames') 
    SelectedFeatures =  Recovery('SelectedFeatures') 
    ReducedFeatures =  Recovery('ReducedFeatures') 
    
    Output_ID = int(D_S_parameters['ID'])

    print('The current Data ID is ', Output_ID)
    
    print('__________________________________________')
