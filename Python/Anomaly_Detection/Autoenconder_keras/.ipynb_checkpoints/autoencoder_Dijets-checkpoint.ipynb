# %% [markdown]
# # Implementation of Anomaly detection using Autoencoders
# Dataset used here is Credit Card Fraud Detection from Kaggle.
#
# ### Import required libraries

# %%
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,normalize, MinMaxScaler
from sklearn.metrics import confusion_matrix, recall_score, accuracy_score, precision_score

from keras import backend as K
print("-------------------------------------------")
print("GPU available: ", tf.test.is_gpu_available())
print("Keras backend: ", K.backend())
print("-------------------------------------------")

# Load layers from keras
from keras.layers import Dense, Input, Concatenate, Flatten, BatchNormalization, Dropout, LeakyReLU
from keras.models import Sequential, Model
from keras.losses import binary_crossentropy
from Disco_tf import distance_corr
from keras.optimizers import Adam
from sklearn.metrics import roc_auc_score
RANDOM_SEED = 2021 
TEST_PCT = 0.3
LABELS = ["Normal","Anomaly"]
# Out:
# -------------------------------------------
# WARNING:tensorflow:From <ipython-input-5-373ecccbb1de>:12: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU available:  False
# Keras backend:  tensorflow
# -------------------------------------------

# %%
# define new loss with distance decorrelation
def decorr(var_1, var_2, weights,kappa):

    def loss(y_true, y_pred):
        #return binary_crossentropy(y_true, y_pred) + distance_corr(var_1, var_2, weights)
        #return distance_corr(var_1, var_2, weights)
        return binary_crossentropy(y_true, y_pred) + kappa * distance_corr(var_1, var_2, weights,power=2)
        #return binary_crossentropy(y_true, y_pred)

    return loss

# %% [markdown]
# ### Read the dataset

# %%
##########################################################
# ------------------------------------------------------ #
# ----------------------- LOADING ---------------------- #
# ------------------------------------------------------ #
##########################################################
# Firstly the model loads the background and signal data, 
# then it removes the attributes first string line, which 
# are the column names, in order to avoid NaN values in 
# the array.

print('         ==== Commencing Initiation ====\n')

### Background
b_name='Input_Background_1.csv'
background = np.genfromtxt(b_name, delimiter=',')
background = background[1:,:]
print("     .Background Loaded..." )
print("     .Background shape: {}".format(background.shape))

### Signal
s_name='Input_Signal_1.csv'
signal = np.genfromtxt(s_name, delimiter=',')
signal = signal[1:,:]
print("     .Signal Loaded...")
print("     .Signal shape: {}\n".format(signal.shape))
# Out:
#          ==== Commencing Initiation ====
#
#      .Background Loaded...
#      .Background shape: (543500, 21)
#      .Signal Loaded...
#      .Signal shape: (522467, 21)

# %%
### Selecting the most pertinent attributes

pertinent_features = [2,3,4,6,10,11,12,14,15,16,18,19,20]

background = background[:,pertinent_features]
signal = signal[:,pertinent_features]

# %%
##########################################################
# ------------------------------------------------------ #
# --------------------- INITIATION --------------------- #
# ------------------------------------------------------ #
##########################################################

# Number of events
total = 50000

# Percentage of background samples on the testing phase
background_percent = 0.99

# Percentage of samples on the training phase
test_size = 0.3

# %%
print('\n          ==== Initiation Complete ====\n')
print('=*='*17 )
print('      ==== Commencing Data Processing ====')

# Percentage of background samples to divide the data-set
dat_set_percent = total/len(background)

# Reducing background samples
_,reduced_background = train_test_split(background, test_size=dat_set_percent)

# Iserting the correct number of signal in streaming

n_signal_samples = int(len(reduced_background)*(1-background_percent))

_,reduced_background = train_test_split(reduced_background, test_size=background_percent)

_,reduced_signal = train_test_split(signal, test_size=n_signal_samples/len(signal))

# Concatenating Signal and the Background sub-sets

data = np.vstack((reduced_background,reduced_signal))

# Normalize Data
print('.Normalizing Data')
data = normalize(data,norm='max',axis=0)

print(".formatted data shape: {}".format(data.shape))
print(".Background shape: {}".format(reduced_background.shape))
print(".Signal shape: {}".format(reduced_signal.shape))

# Creating Labels
print('.Creating Labels')

labels =np.ones((len(data)))
labels[:len(reduced_background)] = 0
# Out:
#           ==== Initiation Complete ====
#
# =*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*=
#       ==== Commencing Data Processing ====
# .Normalizing Data
# .formatted data shape: (50000, 21)
# .Background shape: (49500, 21)
# .Signal shape: (500, 21)
# .Creating Labels

# %%
labels
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
attributes = np.array(["px1","py1","pz1","E1","eta1","phi1","pt1","px2","py2","pz2","E2","eta2",
            "phi2","pt2","Delta_R","M12","MET","S","C","HT","A",'Class'])

dataset = pd.DataFrame(np.hstack((data,labels.reshape(-1,1))),columns = attributes)

# %% [markdown]
# # Exploratory Data Analysis

# %%
dataset.head()
# Out:
#         px1       py1       pz1        E1      eta1      phi1       pt1  \
# 0 -0.215199  0.062430  0.185997  0.193414  0.522813  0.901270  0.195762
# 1  0.121325 -0.148674 -0.063261  0.079749 -0.288969 -0.297516  0.176908
# 2 -0.155155 -0.172319 -0.147897  0.159397 -0.443752 -0.717653  0.212764
# 3 -0.189143  0.109866  0.020976  0.059725  0.102523  0.818380  0.194690
# 4  0.166702 -0.225770  0.019127  0.074198  0.070925 -0.312487  0.259907
#
#         px2       py2       pz2  ...      phi2       pt2   Delta_R       M12  \
# 0  0.226190 -0.048028  0.033064  ... -0.071114  0.210307  0.511263  0.120777
# 1 -0.118909  0.144016  0.136020  ...  0.709196  0.176479  0.639110  0.176598
# 2  0.021228  0.114122  0.071577  ...  0.445215  0.112378  0.632099  0.185119
# 3  0.179608 -0.133481  0.168388  ... -0.213849  0.208059  0.508571  0.119680
# 4 -0.212005  0.207216 -0.218480  ...  0.742869  0.278141  0.545647  0.192906
#
#         MET         S         C        HT         A  Class
# 0  0.103989  0.167914  0.421515  0.221438  0.005896    0.0
# 1  0.027413  0.037478  0.441575  0.179912 -0.005038    0.0
# 2  0.108052  0.010644  0.376870  0.185011 -0.022720    0.0
# 3  0.051229  0.228824  0.489575  0.208876 -0.028347    0.0
# 4  0.048879  0.147364  0.499693  0.274976  0.025359    0.0
#
# [5 rows x 22 columns]

# %%
#check for any  nullvalues 
print("Any nulls in the dataset ",dataset.isnull().values.any() )
print('-------')
print("No. of unique labels ", len(dataset['Class'].unique()))
print("Label values ",dataset.Class.unique())
#0 is for normal credit card transaction
#1 is for fraudulent credit card transaction
print('-------')
print("Break down of the Normal and Fraud Transactions")
print(pd.value_counts(dataset['Class'], sort = True) )
# Out:
# Any nulls in the dataset  False
# -------
# No. of unique labels  2
# Label values  [0. 1.]
# -------
# Break down of the Normal and Fraud Transactions
# 0.0    49500
# 1.0      500
# Name: Class, dtype: int64

# %% [markdown]
# ### Visualize the dataset
# plotting the number of normal and fraud transactions in the dataset.

# %%
#Visualizing the imbalanced dataset
count_classes = pd.value_counts(dataset['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.xticks(range(len(dataset['Class'].unique())), dataset.Class.unique())
plt.title("Frequency by observation number")
plt.xlabel("Class")
plt.ylabel("Number of Observations");

# %% [markdown]
# ### Create train and test dataset
# Checking on the dataset

# %% [markdown]
# The last column in the dataset is our target variable.

# %%
def probability(df):
    mu = np.mean(df, axis=0)
    variance = np.mean((df - mu)**2, axis=0)
    var_dia = np.diag(variance)
    k = len(mu)
    X = df - mu
    p = 1/((2*np.pi)**(k/2)*(np.linalg.det(var_dia)**0.5))* np.exp(-0.5* np.sum(X @ np.linalg.pinv(var_dia) * X,axis=1))
    return p

# %%
raw_data = dataset.values
# The other data points are the electrocadriogram data
data = raw_data[:, 0:-1]
train_data, test_data, train_labels, test_labels = train_test_split(
    data, labels, test_size=0.3, random_state=2021 ,stratify = labels)

p_train = probability(train_data)
p_test = probability(test_data)

# %% [markdown]
# > Use only normal transactions to train the Autoencoder.
#
# Normal data has a value of 0 in the target variable. Using the target variable to create a normal and fraud dataset.

# %%
train_labels = train_labels.astype(bool)
test_labels = test_labels.astype(bool)
#creating normal and fraud datasets
normal_train_data = train_data[~train_labels]
normal_p_train = p_train[~train_labels]

normal_test_data = test_data[~test_labels]
normal_p_test = p_test[~test_labels]

fraud_train_data = train_data[train_labels]
fraud_p_train = p_train[train_labels]

fraud_test_data = test_data[test_labels]
fraud_p_test = p_test[test_labels]
print(" No. of records in Fraud Train Data=",len(fraud_train_data))
print(" No. of records in Normal Train data=",len(normal_train_data))
print(" No. of records in Fraud Test Data=",len(fraud_test_data))
print(" No. of records in Normal Test data=",len(normal_test_data))
# Out:
#  No. of records in Fraud Train Data= 350
#  No. of records in Normal Train data= 34650
#  No. of records in Fraud Test Data= 150
#  No. of records in Normal Test data= 14850

# %% [markdown]
# ### Set the training parameter values

# %% [markdown]
# ### Create the Autoencoder
# The architecture of the autoencoder is shown below.
#
# ![esquema](autoencoder.png)

# %%
nb_epoch = 125
batch_size = 2000
input_dim = normal_train_data.shape[1]
encoding_dim = 8
hidden_dim_1 = int(encoding_dim / 2) #
hidden_dim_2=10  
learning_rate = 0.001

# %%
#input Layer
input_layer = tf.keras.layers.Input(shape=(input_dim, ))
#Encoder
encoder = tf.keras.layers.Dense(encoding_dim, activation="tanh",                                
activity_regularizer=tf.keras.regularizers.l2(learning_rate))(input_layer)
encoder=tf.keras.layers.Dropout(0.2)(encoder)
encoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)
encoder = tf.keras.layers.Dense(hidden_dim_2, activation=tf.nn.leaky_relu)(encoder)
# Decoder
decoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)
decoder=tf.keras.layers.Dropout(0.2)(decoder)
decoder = tf.keras.layers.Dense(encoding_dim, activation='relu')(decoder)
decoder = tf.keras.layers.Dense(input_dim, activation='tanh')(decoder)
#Autoencoder
autoencoder = tf.keras.Model(inputs=input_layer, outputs=decoder)
autoencoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 21)]              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 8)                 176
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                50
# _________________________________________________________________
# dense_15 (Dense)             (None, 4)                 44
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# dense_16 (Dense)             (None, 8)                 40
# _________________________________________________________________
# dense_17 (Dense)             (None, 21)                189
# =================================================================
# Total params: 535
# Trainable params: 535
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Define the callbacks for checkpoints and early stopping

# %%
cp = tf.keras.callbacks.ModelCheckpoint(filepath="autoencoder_fraud.h5",
                               mode='min', monitor='val_loss', verbose=2, save_best_only=True)
# define our early stopping
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.0001,
    patience=10,
    verbose=1, 
    mode='min',
    restore_best_weights=True
)

# %% [markdown]
# ### Compile the Autoencoder

# %%
autoencoder.compile(metrics=['accuracy'],
                    loss='mean_squared_error',
                    optimizer='adam')

# %% [markdown]
# ### Train the Autoencoder

# %%
history = autoencoder.fit(normal_train_data, normal_train_data,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(test_data, test_data),
                    verbose=1,
                    callbacks=[cp, early_stop]
                    ).history
# Out:
# Train on 34650 samples, validate on 15000 samples
# Epoch 1/125
# 32000/34650 [==========================>...] - ETA: 0s - loss: 0.0934 - accuracy: 0.1644
# /home/thiago/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_loss improved from inf to 0.08874, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 2s 65us/sample - loss: 0.0931 - accuracy: 0.1698 - val_loss: 0.0887 - val_accuracy: 0.3264
# Epoch 2/125
# 34650/34650 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.2593
# Epoch 00002: val_loss improved from 0.08874 to 0.08150, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 16us/sample - loss: 0.0858 - accuracy: 0.2593 - val_loss: 0.0815 - val_accuracy: 0.3273
# Epoch 3/125
# 28000/34650 [=======================>......] - ETA: 0s - loss: 0.0804 - accuracy: 0.2821
# Epoch 00003: val_loss improved from 0.08150 to 0.07626, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 0s 9us/sample - loss: 0.0799 - accuracy: 0.2822 - val_loss: 0.0763 - val_accuracy: 0.3273
# Epoch 4/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0753 - accuracy: 0.2827
# Epoch 00004: val_loss improved from 0.07626 to 0.07200, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 2s 52us/sample - loss: 0.0752 - accuracy: 0.2828 - val_loss: 0.0720 - val_accuracy: 0.3273
# Epoch 5/125
# 34650/34650 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.2823
# Epoch 00005: val_loss improved from 0.07200 to 0.06841, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 21us/sample - loss: 0.0713 - accuracy: 0.2823 - val_loss: 0.0684 - val_accuracy: 0.3273
# Epoch 6/125
# 32000/34650 [==========================>...] - ETA: 0s - loss: 0.0680 - accuracy: 0.2829
# Epoch 00006: val_loss improved from 0.06841 to 0.06470, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 20us/sample - loss: 0.0679 - accuracy: 0.2834 - val_loss: 0.0647 - val_accuracy: 0.3273
# Epoch 7/125
# 32000/34650 [==========================>...] - ETA: 0s - loss: 0.0643 - accuracy: 0.3235
# Epoch 00007: val_loss improved from 0.06470 to 0.06085, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 16us/sample - loss: 0.0642 - accuracy: 0.3239 - val_loss: 0.0609 - val_accuracy: 0.3273
# Epoch 8/125
# 32000/34650 [==========================>...] - ETA: 0s - loss: 0.0604 - accuracy: 0.3356
# Epoch 00008: val_loss improved from 0.06085 to 0.05648, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 26us/sample - loss: 0.0602 - accuracy: 0.3361 - val_loss: 0.0565 - val_accuracy: 0.3273
# Epoch 9/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0559 - accuracy: 0.3374
# Epoch 00009: val_loss improved from 0.05648 to 0.05130, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 31us/sample - loss: 0.0558 - accuracy: 0.3374 - val_loss: 0.0513 - val_accuracy: 0.3273
# Epoch 10/125
# 30000/34650 [========================>.....] - ETA: 0s - loss: 0.0521 - accuracy: 0.3360
# Epoch 00010: val_loss improved from 0.05130 to 0.04700, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 17us/sample - loss: 0.0519 - accuracy: 0.3363 - val_loss: 0.0470 - val_accuracy: 0.3273
# Epoch 11/125
# 32000/34650 [==========================>...] - ETA: 0s - loss: 0.0487 - accuracy: 0.3345
# Epoch 00011: val_loss improved from 0.04700 to 0.04357, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 16us/sample - loss: 0.0486 - accuracy: 0.3359 - val_loss: 0.0436 - val_accuracy: 0.3263
# Epoch 12/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0460 - accuracy: 0.3202
# Epoch 00012: val_loss improved from 0.04357 to 0.04057, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 17us/sample - loss: 0.0459 - accuracy: 0.3197 - val_loss: 0.0406 - val_accuracy: 0.2536
# Epoch 13/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0436 - accuracy: 0.2765
# Epoch 00013: val_loss improved from 0.04057 to 0.03814, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 35us/sample - loss: 0.0436 - accuracy: 0.2763 - val_loss: 0.0381 - val_accuracy: 0.2662
# Epoch 14/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0419 - accuracy: 0.2735
# Epoch 00014: val_loss improved from 0.03814 to 0.03637, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 34us/sample - loss: 0.0418 - accuracy: 0.2738 - val_loss: 0.0364 - val_accuracy: 0.2662
# Epoch 15/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0405 - accuracy: 0.2718
# Epoch 00015: val_loss improved from 0.03637 to 0.03520, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 42us/sample - loss: 0.0405 - accuracy: 0.2715 - val_loss: 0.0352 - val_accuracy: 0.2662
# Epoch 16/125
# 32000/34650 [==========================>...] - ETA: 0s - loss: 0.0392 - accuracy: 0.2757
# Epoch 00016: val_loss improved from 0.03520 to 0.03437, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 30us/sample - loss: 0.0392 - accuracy: 0.2749 - val_loss: 0.0344 - val_accuracy: 0.2662
# Epoch 17/125
# 30000/34650 [========================>.....] - ETA: 0s - loss: 0.0385 - accuracy: 0.2792
# Epoch 00017: val_loss improved from 0.03437 to 0.03395, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 15us/sample - loss: 0.0385 - accuracy: 0.2808 - val_loss: 0.0339 - val_accuracy: 0.2661
# Epoch 18/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.3021
# Epoch 00018: val_loss improved from 0.03395 to 0.03365, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 35us/sample - loss: 0.0379 - accuracy: 0.3031 - val_loss: 0.0336 - val_accuracy: 0.2725
# Epoch 19/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0374 - accuracy: 0.3185
# Epoch 00019: val_loss improved from 0.03365 to 0.03347, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 41us/sample - loss: 0.0374 - accuracy: 0.3192 - val_loss: 0.0335 - val_accuracy: 0.3117
# Epoch 20/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.3244
# Epoch 00020: val_loss improved from 0.03347 to 0.03333, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 27us/sample - loss: 0.0370 - accuracy: 0.3247 - val_loss: 0.0333 - val_accuracy: 0.3245
# Epoch 21/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0367 - accuracy: 0.3299
# Epoch 00021: val_loss improved from 0.03333 to 0.03320, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 23us/sample - loss: 0.0367 - accuracy: 0.3292 - val_loss: 0.0332 - val_accuracy: 0.3270
# Epoch 22/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.3296
# Epoch 00022: val_loss improved from 0.03320 to 0.03311, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 39us/sample - loss: 0.0364 - accuracy: 0.3292 - val_loss: 0.0331 - val_accuracy: 0.3237
# Epoch 23/125
# 32000/34650 [==========================>...] - ETA: 0s - loss: 0.0362 - accuracy: 0.3359
# Epoch 00023: val_loss improved from 0.03311 to 0.03308, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 25us/sample - loss: 0.0361 - accuracy: 0.3369 - val_loss: 0.0331 - val_accuracy: 0.3263
# Epoch 24/125
# 32000/34650 [==========================>...] - ETA: 0s - loss: 0.0360 - accuracy: 0.3418
# Epoch 00024: val_loss improved from 0.03308 to 0.03301, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 22us/sample - loss: 0.0360 - accuracy: 0.3418 - val_loss: 0.0330 - val_accuracy: 0.3272
# Epoch 25/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0358 - accuracy: 0.3496
# Epoch 00025: val_loss improved from 0.03301 to 0.03296, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 18us/sample - loss: 0.0358 - accuracy: 0.3501 - val_loss: 0.0330 - val_accuracy: 0.3269
# Epoch 26/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0356 - accuracy: 0.3577
# Epoch 00026: val_loss improved from 0.03296 to 0.03293, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 0s 14us/sample - loss: 0.0356 - accuracy: 0.3578 - val_loss: 0.0329 - val_accuracy: 0.3279
# Epoch 27/125
# 32000/34650 [==========================>...] - ETA: 0s - loss: 0.0355 - accuracy: 0.3622
# Epoch 00027: val_loss improved from 0.03293 to 0.03285, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s
125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0292 - accuracy: 0.4900
# Epoch 00057: val_loss improved from 0.02624 to 0.02621, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 41us/sample - loss: 0.0292 - accuracy: 0.4906 - val_loss: 0.0262 - val_accuracy: 0.5517
# Epoch 58/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0291 - accuracy: 0.4915
# Epoch 00058: val_loss improved from 0.02621 to 0.02603, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 2s 55us/sample - loss: 0.0291 - accuracy: 0.4913 - val_loss: 0.0260 - val_accuracy: 0.5551
# Epoch 59/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0290 - accuracy: 0.4895
# Epoch 00059: val_loss did not improve from 0.02603
# 34650/34650 [==============================] - 2s 57us/sample - loss: 0.0290 - accuracy: 0.4895 - val_loss: 0.0261 - val_accuracy: 0.5445
# Epoch 60/125
# 34650/34650 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.4923
# Epoch 00060: val_loss improved from 0.02603 to 0.02601, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 35us/sample - loss: 0.0289 - accuracy: 0.4923 - val_loss: 0.0260 - val_accuracy: 0.5559
# Epoch 61/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.4895
# Epoch 00061: val_loss did not improve from 0.02601
# 34650/34650 [==============================] - 1s 41us/sample - loss: 0.0290 - accuracy: 0.4895 - val_loss: 0.0261 - val_accuracy: 0.5511
# Epoch 62/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.4928
# Epoch 00062: val_loss did not improve from 0.02601
# 34650/34650 [==============================] - 1s 37us/sample - loss: 0.0288 - accuracy: 0.4924 - val_loss: 0.0261 - val_accuracy: 0.5489
# Epoch 63/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.4946
# Epoch 00063: val_loss improved from 0.02601 to 0.02596, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 43us/sample - loss: 0.0288 - accuracy: 0.4944 - val_loss: 0.0260 - val_accuracy: 0.5503
# Epoch 64/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.4895
# Epoch 00064: val_loss did not improve from 0.02596
# 34650/34650 [==============================] - 1s 34us/sample - loss: 0.0288 - accuracy: 0.4891 - val_loss: 0.0260 - val_accuracy: 0.5474
# Epoch 65/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0287 - accuracy: 0.4899
# Epoch 00065: val_loss did not improve from 0.02596
# 34650/34650 [==============================] - 1s 35us/sample - loss: 0.0287 - accuracy: 0.4897 - val_loss: 0.0261 - val_accuracy: 0.5502
# Epoch 66/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0286 - accuracy: 0.4936
# Epoch 00066: val_loss improved from 0.02596 to 0.02595, saving model to autoencoder_fraud.h5
# 34650/34650 [==============================] - 1s 38us/sample - loss: 0.0287 - accuracy: 0.4931 - val_loss: 0.0260 - val_accuracy: 0.5531
# Epoch 67/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0287 - accuracy: 0.4916
# Epoch 00067: val_loss did not improve from 0.02595
# 34650/34650 [==============================] - 2s 45us/sample - loss: 0.0287 - accuracy: 0.4916 - val_loss: 0.0260 - val_accuracy: 0.5527
# Epoch 68/125
# 34000/34650 [============================>.] - ETA: 0s - loss: 0.0287 - accuracy: 0.4917
# Epoch 00068: val_loss did not improve from 0.02595
# Restoring model weights from the end of the best epoch.
# 34650/34650 [==============================] - 2s 44us/sample - loss: 0.0286 - accuracy: 0.4922 - val_loss: 0.0260 - val_accuracy: 0.5456
# Epoch 00068: early stopping

# %% [markdown]
# Plot training and test loss

# %%
plt.plot(history['loss'], linewidth=2, label='Train')
plt.plot(history['val_loss'], linewidth=2, label='Test')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.ylim(ymin=0.70,ymax=1)
plt.show()

# %% [markdown]
# # Detect Anomalies on test data
# > Anomalies are data points where the reconstruction loss is higher
#
# To calculate the reconstruction loss on test data, predict the test data and calculate the mean square error between the test data and the reconstructed test data.

# %%
test_x_predictions = autoencoder.predict(test_data)
mse = np.mean(np.power(test_data - test_x_predictions, 2), axis=1)
error_df = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': test_labels})

# %% [markdown]
# Plotting the test data points and their respective reconstruction error sets a threshold value to visualize if the threshold value needs to be adjusted.

# %%
threshold_fixed = 0.022
groups = error_df.groupby('True_class')
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold_fixed, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for normal and fraud data")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show()

# %% [markdown]
# Detect anomalies as points where the reconstruction loss is greater than a fixed threshold. Here we see that a value of 52 for the threshold will be good.
# ### Evaluating the performance of the anomaly detection

# %%
threshold_fixed =0.022
pred_y = [1 if e > threshold_fixed else 0 for e in error_df.Reconstruction_error.values]
error_df['pred'] =pred_y
conf_matrix = confusion_matrix(error_df.True_class, pred_y)
plt.figure(figsize=(4, 4))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# print Accuracy, precision and recall
print(" Accuracy: ",accuracy_score(error_df['True_class'], error_df['pred']))
print(" Recall: ",recall_score(error_df['True_class'], error_df['pred']))
print(" Precision: ",precision_score(error_df['True_class'], error_df['pred']))
# Out:
#  Accuracy:  0.5146666666666667
#  Recall:  0.41333333333333333
#  Precision:  0.008547008547008548

# %% [markdown]
# As our dataset is highly imbalanced, we see a high accuracy but a low recall and precision.
# Things to further improve precision and recall would add more relevant features, different architecture for autoencoder, different hyperparameters, or a different algorithm.
# # Conclusion:
# Autoencoder can be used as an anomaly detection algorithm when we have an unbalanced dataset where we have a lot of good examples and only a few anomalies. Autoencoders are trained to minimize reconstruction error. When we train the autoencoders on normal data or good data, we can hypothesize that the anomalies will have higher reconstruction errors than the good or normal data.

# %%
nb_epoch = 175
batch_size = 2000
input_dim = normal_train_data.shape[1]
encoding_dim = 10
hidden_dim_1 = int(encoding_dim / 2) #
hidden_dim_2=10  
learning_rate = 0.001

# %%
#input Layer
input_layer = Input(shape=(input_dim, ))
sample_weights = Input(shape=(1, ))
#Encoder
encoder = tf.keras.layers.Dense(encoding_dim, activation="sigmoid",                                
activity_regularizer=tf.keras.regularizers.l2(learning_rate))(input_layer)
encoder=tf.keras.layers.Dropout(0.2)(encoder)
encoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)
encoder = tf.keras.layers.Dense(hidden_dim_2, activation=tf.nn.leaky_relu)(encoder)
# Decoder
decoder = tf.keras.layers.Dense(hidden_dim_1, activation='relu')(encoder)
decoder=tf.keras.layers.Dropout(0.2)(decoder)
decoder = tf.keras.layers.Dense(encoding_dim, activation='relu')(decoder)
decoder = tf.keras.layers.Dense(input_dim, activation='sigmoid')(decoder)
#Autoencoder
autoencoder = tf.keras.Model(inputs=[input_layer, sample_weights], outputs=decoder)
autoencoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 21)]         0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           220         input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 5)            55          dropout[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           60          dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 5)            55          dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 5)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           60          dropout_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 21)           231         dense_4[0][0]
# ==================================================================================================
# Total params: 681
# Trainable params: 681
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
cp = tf.keras.callbacks.ModelCheckpoint(filepath="autoencoder_fraud.h5",
                               mode='min', monitor='val_loss', verbose=2, save_best_only=True)
# define our early stopping
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.0001,
    patience=20,
    verbose=1, 
    mode='min',
    restore_best_weights=True
)

# %%
opt = Adam(lr=0.001)
autoencoder.compile(optimizer=opt, loss=decorr(input_layer[:,15], decoder[:,15], sample_weights[:,0],600))

# %%
Train = [normal_train_data, np.ones(len(normal_train_data))]
Validation = [test_data , np.ones(len(test_data))]

history = autoencoder.fit(x = Train, y = normal_train_data,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_split=0.1,
                    verbose=1,
                    callbacks=[cp, early_stop]
                    ).history
# Out:
# Train on 31185 samples, validate on 3465 samples
# Epoch 1/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.6767
# /home/thiago/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_loss improved from inf to 0.67970, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 7s 230us/sample - loss: 0.6767 - val_loss: 0.6797
# Epoch 2/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.6454
# Epoch 00002: val_loss improved from 0.67970 to 0.64519, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 140us/sample - loss: 0.6454 - val_loss: 0.6452
# Epoch 3/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.5936
# Epoch 00003: val_loss improved from 0.64519 to 0.58414, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 151us/sample - loss: 0.5936 - val_loss: 0.5841
# Epoch 4/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.5208
# Epoch 00004: val_loss improved from 0.58414 to 0.51467, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 157us/sample - loss: 0.5208 - val_loss: 0.5147
# Epoch 5/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.4350
# Epoch 00005: val_loss improved from 0.51467 to 0.41511, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 173us/sample - loss: 0.4350 - val_loss: 0.4151
# Epoch 6/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.3568
# Epoch 00006: val_loss improved from 0.41511 to 0.29991, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 6s 183us/sample - loss: 0.3568 - val_loss: 0.2999
# Epoch 7/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.3048
# Epoch 00007: val_loss improved from 0.29991 to 0.26052, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 174us/sample - loss: 0.3048 - val_loss: 0.2605
# Epoch 8/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.2779
# Epoch 00008: val_loss improved from 0.26052 to 0.24189, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 163us/sample - loss: 0.2779 - val_loss: 0.2419
# Epoch 9/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.2611
# Epoch 00009: val_loss improved from 0.24189 to 0.23126, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 163us/sample - loss: 0.2611 - val_loss: 0.2313
# Epoch 10/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.2502
# Epoch 00010: val_loss improved from 0.23126 to 0.22003, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 153us/sample - loss: 0.2502 - val_loss: 0.2200
# Epoch 11/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.2365
# Epoch 00011: val_loss improved from 0.22003 to 0.20864, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 171us/sample - loss: 0.2365 - val_loss: 0.2086
# Epoch 12/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.2211
# Epoch 00012: val_loss improved from 0.20864 to 0.19289, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 140us/sample - loss: 0.2211 - val_loss: 0.1929
# Epoch 13/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.2002
# Epoch 00013: val_loss improved from 0.19289 to 0.16961, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 133us/sample - loss: 0.2002 - val_loss: 0.1696
# Epoch 14/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.1666
# Epoch 00014: val_loss improved from 0.16961 to 0.12959, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 137us/sample - loss: 0.1666 - val_loss: 0.1296
# Epoch 15/175
# 31185/31185 [==============================] - ETA: 0s - loss: 0.1043
# Epoch 00015: val_loss improved from 0.12959 to 0.05601, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 131us/sample - loss: 0.1043 - val_loss: 0.0560
# Epoch 16/175
# 31185/31185 [==============================] - ETA: 0s - loss: -0.0121
# Epoch 00016: val_loss improved from 0.05601 to -0.08821, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 132us/sample - loss: -0.0121 - val_loss: -0.0882
# Epoch 17/175
# 31185/31185 [==============================] - ETA: 0s - loss: -0.2177
# Epoch 00017: val_loss improved from -0.08821 to -0.37266, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 134us/sample - loss: -0.2177 - val_loss: -0.3727
# Epoch 18/175
# 31185/31185 [==============================] - ETA: 0s - loss: -0.6380
# Epoch 00018: val_loss improved from -0.37266 to -0.92073, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 140us/sample - loss: -0.6380 - val_loss: -0.9207
# Epoch 19/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1.4100
# Epoch 00019: val_loss improved from -0.92073 to -1.91160, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 135us/sample - loss: -1.4100 - val_loss: -1.9116
# Epoch 20/175
# 31185/31185 [==============================] - ETA: 0s - loss: -2.7689
# Epoch 00020: val_loss improved from -1.91160 to -3.60329, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 144us/sample - loss: -2.7689 - val_loss: -3.6033
# Epoch 21/175
# 31185/31185 [==============================] - ETA: 0s - loss: -4.9885
# Epoch 00021: val_loss improved from -3.60329 to -6.29727, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s
saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 134us/sample - loss: -703.1917 - val_loss: -759.2330
# Epoch 38/175
# 31185/31185 [==============================] - ETA: 0s - loss: -844.6709
# Epoch 00038: val_loss improved from -759.23302 to -906.39400, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 140us/sample - loss: -844.6709 - val_loss: -906.3940
# Epoch 39/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1000.2135
# Epoch 00039: val_loss improved from -906.39400 to -1072.54188, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 140us/sample - loss: -1000.2135 - val_loss: -1072.5419
# Epoch 40/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1186.9060
# Epoch 00040: val_loss improved from -1072.54188 to -1262.56369, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 136us/sample - loss: -1186.9060 - val_loss: -1262.5637
# Epoch 41/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1392.5918
# Epoch 00041: val_loss improved from -1262.56369 to -1476.08163, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 152us/sample - loss: -1392.5918 - val_loss: -1476.0816
# Epoch 42/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1613.2411
# Epoch 00042: val_loss improved from -1476.08163 to -1716.72588, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 171us/sample - loss: -1613.2411 - val_loss: -1716.7259
# Epoch 43/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1885.6017
# Epoch 00043: val_loss improved from -1716.72588 to -1986.07453, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 162us/sample - loss: -1885.6017 - val_loss: -1986.0745
# Epoch 44/175
# 31185/31185 [==============================] - ETA: 0s - loss: -2174.0694
# Epoch 00044: val_loss improved from -1986.07453 to -2289.07050, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 155us/sample - loss: -2174.0694 - val_loss: -2289.0705
# Epoch 45/175
# 31185/31185 [==============================] - ETA: 0s - loss: -2496.3763
# Epoch 00045: val_loss improved from -2289.07050 to -2623.44508, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 146us/sample - loss: -2496.3763 - val_loss: -2623.4451
# Epoch 46/175
# 31185/31185 [==============================] - ETA: 0s - loss: -2872.1775
# Epoch 00046: val_loss improved from -2623.44508 to -2994.41474, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 132us/sample - loss: -2872.1775 - val_loss: -2994.4147
# Epoch 47/175
# 31185/31185 [==============================] - ETA: 0s - loss: -3233.5756
# Epoch 00047: val_loss improved from -2994.41474 to -3405.17659, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 150us/sample - loss: -3233.5756 - val_loss: -3405.1766
# Epoch 48/175
# 31185/31185 [==============================] - ETA: 0s - loss: -3669.0536
# Epoch 00048: val_loss improved from -3405.17659 to -3855.54471, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 154us/sample - loss: -3669.0536 - val_loss: -3855.5447
# Epoch 49/175
# 31185/31185 [==============================] - ETA: 0s - loss: -4190.0191
# Epoch 00049: val_loss improved from -3855.54471 to -4353.14733, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 160us/sample - loss: -4190.0191 - val_loss: -4353.1473
# Epoch 50/175
# 31185/31185 [==============================] - ETA: 0s - loss: -4671.6109
# Epoch 00050: val_loss improved from -4353.14733 to -4895.64577, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 150us/sample - loss: -4671.6109 - val_loss: -4895.6458
# Epoch 51/175
# 31185/31185 [==============================] - ETA: 0s - loss: -5224.2427
# Epoch 00051: val_loss improved from -4895.64577 to -5489.75298, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 155us/sample - loss: -5224.2427 - val_loss: -5489.7530
# Epoch 52/175
# 31185/31185 [==============================] - ETA: 0s - loss: -5894.3663
# Epoch 00052: val_loss improved from -5489.75298 to -6134.34993, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 157us/sample - loss: -5894.3663 - val_loss: -6134.3499
# Epoch 53/175
# 31185/31185 [==============================] - ETA: 0s - loss: -6553.3344
# Epoch 00053: val_loss improved from -6134.34993 to -6829.53903, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s
saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 144us/sample - loss: -924650.1817 - val_loss: -921182.0258
# Epoch 145/175
# 31185/31185 [==============================] - ETA: 0s - loss: -952123.4592
# Epoch 00145: val_loss improved from -921182.02579 to -949091.51380, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 136us/sample - loss: -952123.4592 - val_loss: -949091.5138
# Epoch 146/175
# 31185/31185 [==============================] - ETA: 0s - loss: -984506.8146
# Epoch 00146: val_loss improved from -949091.51380 to -977689.74035, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 151us/sample - loss: -984506.8146 - val_loss: -977689.7403
# Epoch 147/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1016429.5529
# Epoch 00147: val_loss improved from -977689.74035 to -1006996.18994, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 145us/sample - loss: -1016429.5529 - val_loss: -1006996.1899
# Epoch 148/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1038116.9857
# Epoch 00148: val_loss improved from -1006996.18994 to -1036733.24315, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 148us/sample - loss: -1038116.9857 - val_loss: -1036733.2431
# Epoch 149/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1073565.5385
# Epoch 00149: val_loss improved from -1036733.24315 to -1067377.70058, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 143us/sample - loss: -1073565.5385 - val_loss: -1067377.7006
# Epoch 150/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1101678.8845
# Epoch 00150: val_loss improved from -1067377.70058 to -1098479.66071, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 164us/sample - loss: -1101678.8845 - val_loss: -1098479.6607
# Epoch 151/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1134261.6722
# Epoch 00151: val_loss improved from -1098479.66071 to -1130096.25000, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 146us/sample - loss: -1134261.6722 - val_loss: -1130096.2500
# Epoch 152/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1168651.9977
# Epoch 00152: val_loss improved from -1130096.25000 to -1162443.89683, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 163us/sample - loss: -1168651.9977 - val_loss: -1162443.8968
# Epoch 153/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1210730.2970
# Epoch 00153: val_loss improved from -1162443.89683 to -1195596.15909, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 165us/sample - loss: -1210730.2970 - val_loss: -1195596.1591
# Epoch 154/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1227915.4918
# Epoch 00154: val_loss improved from -1195596.15909 to -1229511.42857, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 157us/sample - loss: -1227915.4918 - val_loss: -1229511.4286
# Epoch 155/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1274852.7627
# Epoch 00155: val_loss improved from -1229511.42857 to -1264012.09524, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 149us/sample - loss: -1274852.7627 - val_loss: -1264012.0952
# Epoch 156/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1305102.3595
# Epoch 00156: val_loss improved from -1264012.09524 to -1299236.32107, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 150us/sample - loss: -1305102.3595 - val_loss: -1299236.3211
# Epoch 157/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1344229.8782
# Epoch 00157: val_loss improved from -1299236.32107 to -1335001.53139, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 155us/sample - loss: -1344229.8782 - val_loss: -1335001.5314
# Epoch 158/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1378096.2771
# Epoch 00158: val_loss improved from -1335001.53139 to -1371362.37157, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 154us/sample - loss: -1378096.2771 - val_loss: -1371362.3716
# Epoch 159/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1419650.1760
# Epoch 00159: val_loss improved from -1371362.37157 to -1408735.75144, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 144us/sample - loss: -1419650.1760 - val_loss: -1408735.7514
# Epoch 160/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1463892.8470
# Epoch 00160: val_loss improved from -1408735.75144 to -1446835.35155, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 137us/sample - loss: -1463892.8470 - val_loss: -1446835.3516
# Epoch 161/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1489864.8867
# Epoch 00161: val_loss improved from -1446835.35155 to -1485821.56006, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 138us/sample - loss: -1489864.8867 - val_loss: -1485821.5601
# Epoch 162/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1535427.6312
# Epoch 00162: val_loss improved from -1485821.56006 to -1525199.07576, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 141us/sample - loss: -1535427.6312 - val_loss: -1525199.0758
# Epoch 163/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1574872.5479
# Epoch 00163: val_loss improved from -1525199.07576 to -1565272.22150, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 139us/sample - loss: -1574872.5479 - val_loss: -1565272.2215
# Epoch 164/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1624646.3653
# Epoch 00164: val_loss improved from -1565272.22150 to -1606247.99874, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 148us/sample - loss: -1624646.3653 - val_loss: -1606247.9987
# Epoch 165/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1666329.6914
# Epoch 00165: val_loss improved from -1606247.99874 to -1647945.83947, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 144us/sample - loss: -1666329.6914 - val_loss: -1647945.8395
# Epoch 166/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1701224.3484
# Epoch 00166: val_loss improved from -1647945.83947 to -1690578.87554, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 142us/sample - loss: -1701224.3484 - val_loss: -1690578.8755
# Epoch 167/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1750127.4832
# Epoch 00167: val_loss improved from -1690578.87554 to -1733866.76335, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 145us/sample - loss: -1750127.4832 - val_loss: -1733866.7633
# Epoch 168/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1788097.2440
# Epoch 00168: val_loss improved from -1733866.76335 to -1777940.03716, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 137us/sample - loss: -1788097.2440 - val_loss: -1777940.0372
# Epoch 169/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1841986.0681
# Epoch 00169: val_loss improved from -1777940.03716 to -1822832.95328, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 145us/sample - loss: -1841986.0681 - val_loss: -1822832.9533
# Epoch 170/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1876132.9846
# Epoch 00170: val_loss improved from -1822832.95328 to -1869002.79383, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 145us/sample - loss: -1876132.9846 - val_loss: -1869002.7938
# Epoch 171/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1932942.4216
# Epoch 00171: val_loss improved from -1869002.79383 to -1915583.40260, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 149us/sample - loss: -1932942.4216 - val_loss: -1915583.4026
# Epoch 172/175
# 31185/31185 [==============================] - ETA: 0s - loss: -1982375.0920
# Epoch 00172: val_loss improved from -1915583.40260 to -1963075.27832, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 148us/sample - loss: -1982375.0920 - val_loss: -1963075.2783
# Epoch 173/175
# 31185/31185 [==============================] - ETA: 0s - loss: -2029432.9206
# Epoch 00173: val_loss improved from -1963075.27832 to -2011242.78608, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 141us/sample - loss: -2029432.9206 - val_loss: -2011242.7861
# Epoch 174/175
# 31185/31185 [==============================] - ETA: 0s - loss: -2073866.2658
# Epoch 00174: val_loss improved from -2011242.78608 to -2060384.63889, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 4s 142us/sample - loss: -2073866.2658 - val_loss: -2060384.6389
# Epoch 175/175
# 31185/31185 [==============================] - ETA: 0s - loss: -2122718.5386
# Epoch 00175: val_loss improved from -2060384.63889 to -2110332.47619, saving model to autoencoder_fraud.h5
# 31185/31185 [==============================] - 5s 159us/sample - loss: -2122718.5386 - val_loss: -2110332.4762

# %%
plt.plot(history['loss'], linewidth=2, label='Train')
plt.plot(history['val_loss'], linewidth=2, label='Test')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.ylim(ymin=0.70,ymax=1)
plt.show()

# %%
test_x_predictions = autoencoder.predict([test_data,p_test])
mse = np.mean(np.power(test_data - test_x_predictions, 2), axis=1)
error_df = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': test_labels})

# %%
threshold_fixed = 0.13
groups = error_df.groupby('True_class')
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold_fixed, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for normal and fraud data")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show()

# %%
threshold_fixed =0.13
pred_y = [1 if e > threshold_fixed else 0 for e in error_df.Reconstruction_error.values]
error_df['pred'] =pred_y
conf_matrix = confusion_matrix(error_df.True_class, pred_y)
plt.figure(figsize=(4, 4))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# print Accuracy, precision and recall
print(" Accuracy: ",accuracy_score(error_df['True_class'], error_df['pred']))
print(" Recall: ",recall_score(error_df['True_class'], error_df['pred']))
print(" Precision: ",precision_score(error_df['True_class'], error_df['pred']))
# Out:
#  Accuracy:  0.7108
#  Recall:  0.3933333333333333
#  Precision:  0.013701811425917325
